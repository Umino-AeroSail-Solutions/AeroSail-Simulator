# %%
from Rail_Sizing import R1_max, R2_max, safety_factor

# %% [markdown]
# Loads with safety factor per side for bearing pin

# %%
print(f"safety factor: {safety_factor}")
print(f"bottom beam max load: {R1_max}")
print(f"top beam max load: {R2_max}")
# Out:
# safety factor: 3
# bottom beam max load: 34561.72996247291
# top beam max load: 61633.83396747438

# %% [markdown]
# Things to Do
# - Check Deflectiion
# - Check Buckling
